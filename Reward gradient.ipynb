# %% [markdown]
# $
# \mathscr R ( {\bf W}, \{ {\bf X}^{(i)} \}_i,\{ Y^{(i)} \}_i )
# = \frac
#   {
#         \sum_a
#         {
#            \left(
#                {\bf X}^{(a)} \cdot {\bf W}
#                -
#                \frac{1}{N}
#                \sum_i
#                {
#                    \left(
#                       {\bf X}^{(i)} \cdot {\bf W}
#                    \right)
#                }
#            \right)
#            \left(
#                {Y}^{(a)}
#                -
#                \frac{1}{N}
#                \sum_i
#                {
#                    \left(
#                       {Y}^{(i)}
#                    \right)
#                }
#            \right)
#         }
#   }
#   {
#         \sqrt
#         {
#             \left(
#                 \sum_b
#                 {
#                     \left(
#                            {\bf X}^{(b)} \cdot {\bf W}
#                            -
#                            \frac{1}{N}
#                            \sum_i
#                            {
#                                \left(
#                                   {\bf X}^{(i)} \cdot {\bf W}
#                                \right)
#                            }
#                     \right)^2
#                 }
#             \right)
#             \left(
#                 \sum_c
#                 {
#                     \left(
#                        {Y}^{(c)}
#                        -
#                        \frac{1}{N}
#                        \sum_i
#                        {
#                            \left(
#                               {Y}^{(i)}
#                            \right)
#                        }
#                     \right)^2
#                 }
#             \right)
#         }
#   }
# $

# %% [markdown]
# $
# = \frac
#   {
#         \sum_a
#         {
#            \left(
#                \sum_j
#                \sum_k
#                \sum_l
#                    {X}^{(a)}_{jkl} W_{jkl}
#                -
#                \frac{1}{N}
#                \sum_i
#                {
#                    \left(
#                        \sum_{j'}
#                        \sum_{k'}
#                        \sum_{l'}
#                            {X}^{(i)}_{j'k'l'} W_{j'k'l'}
#                    \right)
#                }
#            \right)
#            \left(
#                {Y}^{(a)}
#                -
#                \frac{1}{N}
#                \sum_i
#                {
#                    \left(
#                       {Y}^{(i)}
#                    \right)
#                }
#            \right)
#         }
#   }
#   {
#         \sqrt
#         {
#             \left(
#                 \sum_b
#                 {
#                     \left(
#                            \sum_{j''}
#                            \sum_{k''}
#                            \sum_{l''}
#                                {X}^{(b)}_{j''k''l''} W_{j''k''l''}
#                            -
#                            \frac{1}{N}
#                            \sum_i
#                            {
#                                \left(
#                                    \sum_{j'''}
#                                    \sum_{k'''}
#                                    \sum_{l'''}
#                                        {X}^{(i)}_{j'''k'''l'''} W_{j'''k'''l'''}
#                                \right)
#                            }
#                     \right)^2
#                 }
#             \right)
#             \left(
#                 \sum_c
#                 {
#                     \left(
#                        {Y}^{(c)}
#                        -
#                        \frac{1}{N}
#                        \sum_i
#                        {
#                            \left(
#                               {Y}^{(i)}
#                            \right)
#                        }
#                     \right)^2
#                 }
#             \right)
#         }
#   }
# $

# %% [markdown]
# Dalla regola del quoziente

# %% [markdown]
# $
# \partial_{W_{xyz}}\mathscr R ( {\bf W}, \{ {\bf X}^{(i)} \}_i,\{ Y^{(i)} \}_i ) = \alpha ( {\bf W}, \{ {\bf X}^{(i)} \}_i,\{ Y^{(i)} \}_i )  - \beta ( {\bf W}, \{ {\bf X}^{(i)} \}_i,\{ Y^{(i)} \}_i ) $
# <br>
#
# Con

# %% [markdown]
# $
# \alpha( {\bf W}, \{ {\bf X}^{(i)} \}_i,\{ Y^{(i)} \}_i ) =
# \frac
# {  \overbrace{
#             \partial_{W_{xyz}} \left\{
#                                             \sum_a
#                                         {
#                                            \left(
#                                                \sum_j
#                                                \sum_k
#                                                \sum_l
#                                                    {X}^{(a)}_{jkl} W_{jkl}
#                                                -
#                                                \frac{1}{N}
#                                                \sum_i
#                                                {
#                                                    \left(
#                                                        \sum_{j'}
#                                                        \sum_{k'}
#                                                        \sum_{l'}
#                                                            {X}^{(i)}_{j'k'l'} W_{j'k'l'}
#                                                    \right)
#                                                }
#                                            \right)
#                                            \left(
#                                                {Y}^{(a)}
#                                                -
#                                                \frac{1}{N}
#                                                \sum_i
#                                                {
#                                                    \left(
#                                                       {Y}^{(i)}
#                                                    \right)
#                                                }
#                                            \right)
#                                         }
#                               \right\}
#      }^{A}
#                               \sqrt
#                                 {
#                                     \left(
#                                         \sum_b
#                                         {
#                                             \left(
#                                                    {\bf X}^{(b)} \cdot {\bf W}
#                                                    -
#                                                    \frac{1}{N}
#                                                    \sum_i
#                                                    {
#                                                        \left(
#                                                           {\bf X}^{(i)} \cdot {\bf W}
#                                                        \right)
#                                                    }
#                                             \right)^2
#                                         }
#                                     \right)
#                                     \left(
#                                         \sum_c
#                                         {
#                                             \left(
#                                                {Y}^{(c)}
#                                                -
#                                                \frac{1}{N}
#                                                \sum_i
#                                                {
#                                                    \left(
#                                                       {Y}^{(i)}
#                                                    \right)
#                                                }
#                                             \right)^2
#                                         }
#                                     \right)
#                                 }
#                                 %
#                                 %
# }
# {
#             \left(
#                 \sum_b
#                 {
#                     \left(
#                            {\bf X}^{(b)} \cdot {\bf W}
#                            -
#                            \frac{1}{N}
#                            \sum_i
#                            {
#                                \left(
#                                   {\bf X}^{(i)} \cdot {\bf W}
#                                \right)
#                            }
#                     \right)^2
#                 }
#             \right)
#             \left(
#                 \sum_c
#                 {
#                     \left(
#                        {Y}^{(c)}
#                        -
#                        \frac{1}{N}
#                        \sum_i
#                        {
#                            \left(
#                               {Y}^{(i)}
#                            \right)
#                        }
#                     \right)^2
#                 }
#             \right)
# }
# $

# %% [markdown]
# $
# \beta( {\bf W}, \{ {\bf X}^{(i)} \}_i,\{ Y^{(i)} \}_i ) =
# \frac
# {
# \overbrace
# {
#             \partial_{W_{xyz}} \left\{
#                                   \sqrt
#                                 {
#                                     \left(
#                                         \sum_b
#                                         {
#                                             \left(
#                                                    {\bf X}^{(b)} \cdot {\bf W}
#                                                    -
#                                                    \frac{1}{N}
#                                                    \sum_i
#                                                    {
#                                                        \left(
#                                                           {\bf X}^{(i)} \cdot {\bf W}
#                                                        \right)
#                                                    }
#                                             \right)^2
#                                         }
#                                     \right)
#                                     \left(
#                                         \sum_c
#                                         {
#                                             \left(
#                                                {Y}^{(c)}
#                                                -
#                                                \frac{1}{N}
#                                                \sum_i
#                                                {
#                                                    \left(
#                                                       {Y}^{(i)}
#                                                    \right)
#                                                }
#                                             \right)^2
#                                         }
#                                     \right)
#                                 }
#                               \right\}
# }^{B}
#                                 %
#                                \sum_a
#                                         {
#                                            \left(
#                                                \sum_j
#                                                \sum_k
#                                                \sum_l
#                                                    {X}^{(a)}_{jkl} W_{jkl}
#                                                -
#                                                \frac{1}{N}
#                                                \sum_i
#                                                {
#                                                    \left(
#                                                        \sum_{j'}
#                                                        \sum_{k'}
#                                                        \sum_{l'}
#                                                            {X}^{(i)}_{j'k'l'} W_{j'k'l'}
#                                                    \right)
#                                                }
#                                            \right)
#                                            \left(
#                                                {Y}^{(a)}
#                                                -
#                                                \frac{1}{N}
#                                                \sum_i
#                                                {
#                                                    \left(
#                                                       {Y}^{(i)}
#                                                    \right)
#                                                }
#                                            \right)
#                                         }
# }
# {
#             \left(
#                 \sum_b
#                 {
#                     \left(
#                            {\bf X}^{(b)} \cdot {\bf W}
#                            -
#                            \frac{1}{N}
#                            \sum_i
#                            {
#                                \left(
#                                   {\bf X}^{(i)} \cdot {\bf W}
#                                \right)
#                            }
#                     \right)^2
#                 }
#             \right)
#             \left(
#                 \sum_c
#                 {
#                     \left(
#                        {Y}^{(c)}
#                        -
#                        \frac{1}{N}
#                        \sum_i
#                        {
#                            \left(
#                               {Y}^{(i)}
#                            \right)
#                        }
#                     \right)^2
#                 }
#             \right)
# }
# $

# %% [markdown]
# # Calcoliamo $A$

# %% [markdown]
# $\partial_{W_{xyz}} \left\{
#                                             \sum_a
#                                         {
#                                            \left(
#                                                \sum_j
#                                                \sum_k
#                                                \sum_l
#                                                    {X}^{(a)}_{jkl} W_{jkl}
#                                                -
#                                                \frac{1}{N}
#                                                \sum_i
#                                                {
#                                                    \left(
#                                                        \sum_{j'}
#                                                        \sum_{k'}
#                                                        \sum_{l'}
#                                                            {X}^{(i)}_{j'k'l'} W_{j'k'l'}
#                                                    \right)
#                                                }
#                                            \right)
#                                            \left(
#                                                {Y}^{(a)}
#                                                -
#                                                \frac{1}{N}
#                                                \sum_i
#                                                {
#                                                    \left(
#                                                       {Y}^{(i)}
#                                                    \right)
#                                                }
#                                            \right)
#                                         }
#                               \right\}$

# %% [markdown]
# $\sum_a
#        {
#        \partial_{W_{xyz}} \left\{
#                                            \left(
#                                                \sum_j
#                                                \sum_k
#                                                \sum_l
#                                                    {X}^{(a)}_{jkl} W_{jkl}
#                                                -
#                                                \frac{1}{N}
#                                                \sum_i
#                                                {
#                                                    \left(
#                                                        \sum_{j'}
#                                                        \sum_{k'}
#                                                        \sum_{l'}
#                                                            {X}^{(i)}_{j'k'l'} W_{j'k'l'}
#                                                    \right)
#                                                }
#                                            \right)
#                                            \left(
#                                                {Y}^{(a)}
#                                                -
#                                                \frac{1}{N}
#                                                \sum_i
#                                                {
#                                                    \left(
#                                                       {Y}^{(i)}
#                                                    \right)
#                                                }
#                                            \right)
#                               \right\}
#         }$

# %% [markdown]
# $\sum_a
#        {
#        \partial_{W_{xyz}} \left\{
#                                            \left(
#                                                \sum_j
#                                                \sum_k
#                                                \sum_l
#                                                    {X}^{(a)}_{jkl} W_{jkl}
#                                                -
#                                                \frac{1}{N}
#                                                \sum_i
#                                                {
#                                                    \left(
#                                                        \sum_{j'}
#                                                        \sum_{k'}
#                                                        \sum_{l'}
#                                                            {X}^{(i)}_{j'k'l'} W_{j'k'l'}
#                                                    \right)
#                                                }
#                                            \right)
#                               \right\}
#                                            \left(
#                                                {Y}^{(a)}
#                                                -
#                                                \frac{1}{N}
#                                                \sum_i
#                                                {
#                                                    \left(
#                                                       {Y}^{(i)}
#                                                    \right)
#                                                }
#                                            \right)
#         }$

# %% [markdown]
# $\sum_a
#        {
#                     \left(
#                                \partial_{W_{xyz}} \left\{
#                                                \sum_j
#                                                \sum_k
#                                                \sum_l
#                                                    {X}^{(a)}_{jkl} W_{jkl}
#                                \right\}
#                                                -
#                                \frac{1}{N}
#                                \partial_{W_{xyz}} \left\{
#                                                \sum_i
#                                                {
#                                                    \left(
#                                                        \sum_{j'}
#                                                        \sum_{k'}
#                                                        \sum_{l'}
#                                                            {X}^{(i)}_{j'k'l'} W_{j'k'l'}
#                                                    \right)
#                                                }
#                                \right\}
#                     \right)
#                                            \left(
#                                                {Y}^{(a)}
#                                                -
#                                                \frac{1}{N}
#                                                \sum_i
#                                                {
#                                                    \left(
#                                                       {Y}^{(i)}
#                                                    \right)
#                                                }
#                                            \right)
#         }$

# %% [markdown]
# $\sum_a
#        {
#                     \left(
#                                {X}^{(a)}_{xyz}
#                                                -
#                                \frac{1}{N}
#                                                \sum_i
#                                                {
#                                                            {X}^{(i)}_{xyz}
#                                                }
#                     \right)
#                                            \left(
#                                                {Y}^{(a)}
#                                                -
#                                                \frac{1}{N}
#                                                \sum_i
#                                                {
#                                                    \left(
#                                                       {Y}^{(i)}
#                                                    \right)
#                                                }
#                                            \right)
#         }$

# %% [markdown]
# Da cui

# %% [markdown]
# $\alpha =
# \frac{
#        \sum_a
#        {
#                     \left(
#                                {X}^{(a)}_{xyz}
#                                                -
#                                \frac{1}{N}
#                                                \sum_i
#                                                {
#                                                            {X}^{(i)}_{xyz}
#                                                }
#                     \right)
#                                            \left(
#                                                {Y}^{(a)}
#                                                -
#                                                \frac{1}{N}
#                                                \sum_i
#                                                {
#                                                    \left(
#                                                       {Y}^{(i)}
#                                                    \right)
#                                                }
#                                            \right)
#         }
# }
# {
# \sqrt
#                                 {
#                                     \left(
#                                         \sum_b
#                                         {
#                                             \left(
#                                                    {\bf X}^{(b)} \cdot {\bf W}
#                                                    -
#                                                    \frac{1}{N}
#                                                    \sum_i
#                                                    {
#                                                        \left(
#                                                           {\bf X}^{(i)} \cdot {\bf W}
#                                                        \right)
#                                                    }
#                                             \right)^2
#                                         }
#                                     \right)
#                                     \left(
#                                         \sum_c
#                                         {
#                                             \left(
#                                                {Y}^{(c)}
#                                                -
#                                                \frac{1}{N}
#                                                \sum_i
#                                                {
#                                                    \left(
#                                                       {Y}^{(i)}
#                                                    \right)
#                                                }
#                                             \right)^2
#                                         }
#                                     \right)
#                                 }
# }$

# %% [markdown]
# # Calcoliamo $B$

# %% [markdown]
# $
# \partial_{W_{xyz}}
# \left\{
#  \sqrt
#         {
#             \left(
#                 \sum_b
#                 {
#                     \left(
#                            \sum_{j''}
#                            \sum_{k''}
#                            \sum_{l''}
#                                {X}^{(b)}_{j''k''l''} W_{j''k''l''}
#                            -
#                            \frac{1}{N}
#                            \sum_i
#                            {
#                                \left(
#                                    \sum_{j'''}
#                                    \sum_{k'''}
#                                    \sum_{l'''}
#                                        {X}^{(i)}_{j'''k'''l'''} W_{j'''k'''l'''}
#                                \right)
#                            }
#                     \right)^2
#                 }
#             \right)
#             \left(
#                 \sum_c
#                 {
#                     \left(
#                        {Y}^{(c)}
#                        -
#                        \frac{1}{N}
#                        \sum_i
#                        {
#                            \left(
#                               {Y}^{(i)}
#                            \right)
#                        }
#                     \right)^2
#                 }
#             \right)
#         }
# \right\}
# $

# %% [markdown]
# $
# =
# \frac
# {
#     \partial_{W_{xyz}}
#     \left\{
#          \left(
#                 \sum_b
#                 {
#                     \left(
#                            \sum_{j''}
#                            \sum_{k''}
#                            \sum_{l''}
#                                {X}^{(b)}_{j''k''l''} W_{j''k''l''}
#                            -
#                            \frac{1}{N}
#                            \sum_i
#                            {
#                                \left(
#                                    \sum_{j'''}
#                                    \sum_{k'''}
#                                    \sum_{l'''}
#                                        {X}^{(i)}_{j'''k'''l'''} W_{j'''k'''l'''}
#                                \right)
#                            }
#                     \right)^2
#                 }
#             \right)
#             \left(
#                 \sum_c
#                 {
#                     \left(
#                        {Y}^{(c)}
#                        -
#                        \frac{1}{N}
#                        \sum_i
#                        {
#                            \left(
#                               {Y}^{(i)}
#                            \right)
#                        }
#                     \right)^2
#                 }
#             \right)
#     \right\}
# }
# {
#     2
#      \sqrt
#         {
#             \left(
#                 \sum_b
#                 {
#                     \left(
#                            \sum_{j''}
#                            \sum_{k''}
#                            \sum_{l''}
#                                {X}^{(b)}_{j''k''l''} W_{j''k''l''}
#                            -
#                            \frac{1}{N}
#                            \sum_i
#                            {
#                                \left(
#                                    \sum_{j'''}
#                                    \sum_{k'''}
#                                    \sum_{l'''}
#                                        {X}^{(i)}_{j'''k'''l'''} W_{j'''k'''l'''}
#                                \right)
#                            }
#                     \right)^2
#                 }
#             \right)
#             \left(
#                 \sum_c
#                 {
#                     \left(
#                        {Y}^{(c)}
#                        -
#                        \frac{1}{N}
#                        \sum_i
#                        {
#                            \left(
#                               {Y}^{(i)}
#                            \right)
#                        }
#                     \right)^2
#                 }
#             \right)
#         }
# }
# $

# %% [markdown]
# $
# =
# \frac
# {
#     \partial_{W_{xyz}}
#     \left\{
#                 \sum_b
#                 {
#                     \left(
#                            \sum_{j''}
#                            \sum_{k''}
#                            \sum_{l''}
#                                {X}^{(b)}_{j''k''l''} W_{j''k''l''}
#                            -
#                            \frac{1}{N}
#                            \sum_i
#                            {
#                                \left(
#                                    \sum_{j'''}
#                                    \sum_{k'''}
#                                    \sum_{l'''}
#                                        {X}^{(i)}_{j'''k'''l'''} W_{j'''k'''l'''}
#                                \right)
#                            }
#                     \right)^2
#                 }
#     \right\}
#                 \left(
#                 \sum_c
#                 {
#                     \left(
#                        {Y}^{(c)}
#                        -
#                        \frac{1}{N}
#                        \sum_i
#                        {
#                            \left(
#                               {Y}^{(i)}
#                            \right)
#                        }
#                     \right)^2
#                 }
#             \right)
# }
# {
#     2 \sqrt
#         {
#             \left(
#                 \sum_b
#                 {
#                     \left(
#                            {\bf X}^{(b)} \cdot {\bf W}
#                            -
#                            \frac{1}{N}
#                            \sum_i
#                            {
#                                \left(
#                                   {\bf X}^{(i)} \cdot {\bf W}
#                                \right)
#                            }
#                     \right)^2
#                 }
#             \right)
#             \left(
#                 \sum_c
#                 {
#                     \left(
#                        {Y}^{(c)}
#                        -
#                        \frac{1}{N}
#                        \sum_i
#                        {
#                            \left(
#                               {Y}^{(i)}
#                            \right)
#                        }
#                     \right)^2
#                 }
#             \right)
#         }
# }
# $

# %% [markdown]
# $
# =
# 2 \frac
# {
#     \left(
#          \sum_b
#                 {
#                     \left(
#                            {\bf X}^{(b)} \cdot {\bf W}
#                            -
#                            \frac{1}{N}
#                            \sum_i
#                            {
#                                \left(
#                                   {\bf X}^{(i)} \cdot {\bf W}
#                                \right)
#                            }
#                     \right)
#                }
#     \right)
#     \partial_{W_{xyz}}
#     \left\{
#          \left(
#                 {
#                     \left(
#                            \sum_{j''}
#                            \sum_{k''}
#                            \sum_{l''}
#                                {X}^{(b)}_{j''k''l''} W_{j''k''l''}
#                            -
#                            \frac{1}{N}
#                            \sum_i
#                            {
#                                \left(
#                                    \sum_{j'''}
#                                    \sum_{k'''}
#                                    \sum_{l'''}
#                                        {X}^{(i)}_{j'''k'''l'''} W_{j'''k'''l'''}
#                                \right)
#                            }
#                     \right)
#                 }
#             \right)
#     \right\}
#                 \left(
#                 \sum_c
#                 {
#                     \left(
#                        {Y}^{(c)}
#                        -
#                        \frac{1}{N}
#                        \sum_i
#                        {
#                            \left(
#                               {Y}^{(i)}
#                            \right)
#                        }
#                     \right)^2
#                 }
#             \right)
# }
# {
#     2 \sqrt
#         {
#             \left(
#                 \sum_b
#                 {
#                     \left(
#                            {\bf X}^{(b)} \cdot {\bf W}
#                            -
#                            \frac{1}{N}
#                            \sum_i
#                            {
#                                \left(
#                                   {\bf X}^{(i)} \cdot {\bf W}
#                                \right)
#                            }
#                     \right)^2
#                 }
#             \right)
#             \left(
#                 \sum_c
#                 {
#                     \left(
#                        {Y}^{(c)}
#                        -
#                        \frac{1}{N}
#                        \sum_i
#                        {
#                            \left(
#                               {Y}^{(i)}
#                            \right)
#                        }
#                     \right)^2
#                 }
#             \right)
#         }
# }
# $

# %% [markdown]
# $
# =
# \frac
# {
#     \left(
#          \sum_b
#                 {
#                     \left(
#                            {\bf X}^{(b)} \cdot {\bf W}
#                            -
#                            \frac{1}{N}
#                            \sum_i
#                            {
#                                \left(
#                                   {\bf X}^{(i)} \cdot {\bf W}
#                                \right)
#                            }
#                     \right)
#                }
#     \right)
#     \left\{
#                 {
#                            X^{(b)}_{xyz}
#                            -
#                            \frac{1}{N}
#                            \sum_i
#                            {
#                                       X^{(i)}_{xyz}
#                            }
#                 }
#     \right\}
#                 \left(
#                 \sum_c
#                 {
#                     \left(
#                        {Y}^{(c)}
#                        -
#                        \frac{1}{N}
#                        \sum_i
#                        {
#                            \left(
#                               {Y}^{(i)}
#                            \right)
#                        }
#                     \right)^2
#                 }
#             \right)
# }
# {
#     \sqrt
#         {
#             \left(
#                 \sum_b
#                 {
#                     \left(
#                            {\bf X}^{(b)} \cdot {\bf W}
#                            -
#                            \frac{1}{N}
#                            \sum_i
#                            {
#                                \left(
#                                   {\bf X}^{(i)} \cdot {\bf W}
#                                \right)
#                            }
#                     \right)^2
#                 }
#             \right)
#             \left(
#                 \sum_c
#                 {
#                     \left(
#                        {Y}^{(c)}
#                        -
#                        \frac{1}{N}
#                        \sum_i
#                        {
#                            \left(
#                               {Y}^{(i)}
#                            \right)
#                        }
#                     \right)^2
#                 }
#             \right)
#         }
# }
# $

# %% [markdown]
# Da cui

# %% [markdown]
# $
# \beta = B
# \frac{
#         \sum_a
#         {
#            \left(
#                {\bf X}^{(a)} \cdot {\bf W}
#                -
#                \frac{1}{N}
#                \sum_i
#                {
#                    \left(
#                       {\bf X}^{(i)} \cdot {\bf W}
#                    \right)
#                }
#            \right)
#            \left(
#                {Y}^{(a)}
#                -
#                \frac{1}{N}
#                \sum_i
#                {
#                    \left(
#                       {Y}^{(i)}
#                    \right)
#                }
#            \right)
#         }
# }
# {
#             \left(
#                 \sum_b
#                 {
#                     \left(
#                            {\bf X}^{(b)} \cdot {\bf W}
#                            -
#                            \frac{1}{N}
#                            \sum_i
#                            {
#                                \left(
#                                   {\bf X}^{(i)} \cdot {\bf W}
#                                \right)
#                            }
#                     \right)^2
#                 }
#             \right)
#             \left(
#                 \sum_c
#                 {
#                     \left(
#                        {Y}^{(c)}
#                        -
#                        \frac{1}{N}
#                        \sum_i
#                        {
#                            \left(
#                               {Y}^{(i)}
#                            \right)
#                        }
#                     \right)^2
#                 }
#             \right)
# }
# $ <br>
# $=
# \frac
# {
#     \left(
#          \sum_b
#                 {
#                     \left(
#                            {\bf X}^{(b)} \cdot {\bf W}
#                            -
#                            \frac{1}{N}
#                            \sum_i
#                            {
#                                \left(
#                                   {\bf X}^{(i)} \cdot {\bf W}
#                                \right)
#                            }
#                     \right)
#                }
#     \right)
#     \left\{
#
#                 {
#                            X^{(b)}_{xyz}
#                            -
#                            \frac{1}{N}
#                            \sum_i
#                            {
#                                       X^{(i)}_{xyz}
#                            }
#                 }
#     \right\}
#                 \left(
#                 \sum_c
#                 {
#                     \left(
#                        {Y}^{(c)}
#                        -
#                        \frac{1}{N}
#                        \sum_i
#                        {
#                            \left(
#                               {Y}^{(i)}
#                            \right)
#                        }
#                     \right)^2
#                 }
#             \right)
# }
# {
#     \sqrt
#         {
#             \left(
#                 \sum_b
#                 {
#                     \left(
#                            {\bf X}^{(b)} \cdot {\bf W}
#                            -
#                            \frac{1}{N}
#                            \sum_i
#                            {
#                                \left(
#                                   {\bf X}^{(i)} \cdot {\bf W}
#                                \right)
#                            }
#                     \right)^2
#                 }
#             \right)
#             \left(
#                 \sum_c
#                 {
#                     \left(
#                        {Y}^{(c)}
#                        -
#                        \frac{1}{N}
#                        \sum_i
#                        {
#                            \left(
#                               {Y}^{(i)}
#                            \right)
#                        }
#                     \right)^2
#                 }
#             \right)
#         }
# }
# \frac{
#         \sum_a
#         {
#            \left(
#                {\bf X}^{(a)} \cdot {\bf W}
#                -
#                \frac{1}{N}
#                \sum_i
#                {
#                    \left(
#                       {\bf X}^{(i)} \cdot {\bf W}
#                    \right)
#                }
#            \right)
#            \left(
#                {Y}^{(a)}
#                -
#                \frac{1}{N}
#                \sum_i
#                {
#                    \left(
#                       {Y}^{(i)}
#                    \right)
#                }
#            \right)
#         }
# }
# {
#             \left(
#                 \sum_b
#                 {
#                     \left(
#                            {\bf X}^{(b)} \cdot {\bf W}
#                            -
#                            \frac{1}{N}
#                            \sum_i
#                            {
#                                \left(
#                                   {\bf X}^{(i)} \cdot {\bf W}
#                                \right)
#                            }
#                     \right)^2
#                 }
#             \right)
#             \left(
#                 \sum_c
#                 {
#                     \left(
#                        {Y}^{(c)}
#                        -
#                        \frac{1}{N}
#                        \sum_i
#                        {
#                            \left(
#                               {Y}^{(i)}
#                            \right)
#                        }
#                     \right)^2
#                 }
#             \right)
# }
# $

# %% [markdown]
# $
# =
# \frac{
#     \langle
#             {\bf 1},
#             XW - \bar{XW}
#     \rangle
#     \langle
#             {\bf 1},
#             X_{xyz} - \bar{X_{xyz}}
#     \rangle
#     \langle
#         XW - \bar{XW},Y  - \bar{Y}
#     \rangle
#     || Y  - \bar{Y}  ||^{2}
# }
# {
#     || XW - \bar{XW} ||^{3}
#     || Y  - \bar{Y}  ||^{3}
# }
# $

# %% [markdown]
# $
# =
# \frac{
#     \langle
#             {\bf 1},
#             XW - \bar{XW}
#     \rangle
#     \langle
#             {\bf 1},
#             X_{xyz} - \bar{X_{xyz}}
#     \rangle
#     \langle
#         XW - \bar{XW},Y  - \bar{Y}
#     \rangle
# }
# {
#     || XW - \bar{XW} ||^{3}
#     || Y  - \bar{Y}  ||
# }
# $

# %%
import numpy as np
import jax.numpy as jnp
import jax

def corr(u,v):
    u_c = u - u.mean()
    v_c = v - v.mean()
    norma_u_c = jnp.linalg.norm(u_c)
    norma_v_c = jnp.linalg.norm(v_c)
    return (u_c @ v_c) / (norma_u_c * norma_v_c)
def r(W,X,Y):
    u = jax.vmap(lambda x: (x * W).sum() )(X)
    return corr(u,Y)
N = 10000
W = np.random.normal(size = (10,10,10))
X = np.random.normal(size = (N,10,10,10))
Y = jax.vmap(lambda x : x.sum())(X)

grad = jax.grad(r)
corretto = grad(W,X,Y)

# %%
def handcrafted_grad(W,X,Y):
    X_bar = X.mean(axis = 0)
    Y_hat = jax.vmap(lambda x: (x * W).sum() )(X)
    A_1   = ((X - X_bar) * (Y - Y.mean())[:,None,None,None] ).sum(axis = 0)
    A     = A_1 / (jnp.linalg.norm(Y_hat - Y_hat.mean()) * jnp.linalg.norm(Y - Y.mean()))
    
    B_1   = ( (Y_hat - Y_hat.mean())[:,None,None,None]*(X - X_bar) ).sum(axis = 0)* ((Y_hat - Y_hat.mean()) @ (Y - Y.mean()))
    B_2   = jnp.linalg.norm(Y_hat - Y_hat.mean())**3 * jnp.linalg.norm(Y - Y.mean())
    B     = B_1/B_2
    return A - B
predetto = handcrafted_grad(W,X,Y)

# %%
import matplotlib.pyplot as plt
axs = plt.figure(figsize = (15,2)).subplots(nrows = 1, ncols = 3).flatten()
axs[0].set_title("Derivata automatica")
axs[0].plot(corretto.flatten())
axs[1].set_title("Derivata artigianale")
axs[1].plot(predetto.flatten())
axs[2].plot(predetto.flatten() - corretto.flatten())

# %%
r(W,X,Y)
# Out:
# DeviceArray(1.0000001, dtype=float32)
